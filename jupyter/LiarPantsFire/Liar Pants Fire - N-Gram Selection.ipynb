# %%
import sys
sys.path.insert(1, '../..')

import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../../data/processed/liarpantsfire_dataset.csv", lineterminator="\n")
data.head()
# Out:
#            id                                          statement        label  \
# 0   2635.json  Says the Annies List political group supports ...        false
# 1  10540.json  When did the decline of coal start? It started...    half-true
# 2    324.json  Hillary Clinton agrees with John McCain "by vo...  mostly-true
# 3   1123.json  Health care reform legislation is likely to ma...        false
# 4   9028.json  The economic turnaround started at the end of ...    half-true
#
#          tvt2      tvt2_1      tvt2_2      tvt2_3
# 0  validation  validation    training    training
# 1    training    training  validation    training
# 2    training    training  validation  validation
# 3    training  validation    testting    training
# 4    training    training    testting    training

# %%
statements = data['statement'].tolist()
comp = [len(s.split(" ")) for s in statements]
print("Average words : ", sum(comp)/len(comp))
print("Max words : ", max(comp))
print("Data : ", len(comp))
# Out:
# Average words :  17.991947463059965
# Max words :  302
# Data :  12791

# %%
# labels_str = ['rumour', 'non-rumour']
label_type = "label"
labels_str = data[label_type].unique().tolist()
labels_str
# Out:
# ['false', 'half-true', 'mostly-true', 'true', 'barely-true', 'pants-fire']

# %%
labels = []
for i, d in data.iterrows():
    lab = labels_str.index(d[label_type])
    labels.append(lab)
labels[:10]
# Out:
# [0, 1, 2, 0, 1, 3, 4, 1, 1, 2]

# %%
import string
import nltk
from nltk.tokenize import TweetTokenizer

tokenizer = TweetTokenizer(reduce_len=True)


def text2unigrams(text):
    texts = tokenizer.tokenize(text.encode('ascii', 'ignore').decode('utf8'))
    texts = [t for t in texts if t not in string.punctuation]
    texts = [t for t in texts if t not in ['URL', '‘', '’']]
    
    unigrams = texts
    
    return unigrams


def text2bigrams(text):
    texts = tokenizer.tokenize(text.encode('ascii', 'ignore').decode('utf8'))
    texts = [t for t in texts if t not in string.punctuation]
    texts = [t for t in texts if t not in ['URL', '‘', '’']]
    
    bigrams = nltk.bigrams(texts)
    
    return bigrams


def text2trigrams(text):
    texts = tokenizer.tokenize(text.encode('ascii', 'ignore').decode('utf8'))
    texts = [t for t in texts if t not in string.punctuation]
    texts = [t for t in texts if t not in ['URL', '‘', '’']]
    
    trigrams = nltk.trigrams(texts)
    
    return trigrams


def custom_vectors_generation(texts, vector_terms):
    vectors = []
    for text in texts:
        bigrams = text2bigrams(text)
        trigrams = text2trigrams(text)

        init_vec = [0.0 for _ in range(len(vector_terms) + 1)]
        for bgr in bigrams:
            if bgr in vector_terms:
                idx = vector_terms.index(bgr)
                init_vec[idx] = 1.0
            else:
                init_vec[-1] = 1.0
        for tgr in trigrams:
            if tgr in vector_terms:
                idx = vector_terms.index(tgr)
                init_vec[idx] = 1.0
            else:
                init_vec[-1] = 1.0
        vectors.append(init_vec)
    
    return vectors

# %%
texts = data['statement'].tolist()
# vectors = bigrams_vectors_generation(texts)

# %%
import nltk
from nltk.collocations import *

top_n = 2000
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

finder2 = BigramCollocationFinder.from_words([])
finder3 = TrigramCollocationFinder.from_words([])

# generating bigram and trigram
for text in texts:
    unigrams = text2unigrams(text)
    bigrams = text2bigrams(text)
    trigrams = text2trigrams(text)
    
    for ngrm in unigrams:
        if ngrm not in finder2.word_fd:
            finder2.word_fd[ngrm] = 0
        finder2.word_fd[ngrm] += 1
        finder2.N += 1
        
        if ngrm not in finder3.word_fd:
            finder3.word_fd[ngrm] = 0
        finder3.word_fd[ngrm] += 1
        finder3.N += 1
    
    for ngrm in bigrams:
        term = ngrm
        
        if term not in finder2.ngram_fd:
            finder2.ngram_fd[term] = 0
            
        finder2.ngram_fd[term] += 1

    for ngrm in trigrams:
        term = ngrm
        
        if term not in finder3.ngram_fd:
            finder3.ngram_fd[term] = 0
            
        finder3.ngram_fd[term] += 1
        
# only bigrams that appear 3+ times
finder2.apply_freq_filter(3)
finder3.apply_freq_filter(3)

combined = []
for res in finder2.score_ngrams(bigram_measures.pmi):
    combined.append(res)
for res in finder3.score_ngrams(trigram_measures.pmi):
    combined.append(res)
combined = sorted(combined, key=lambda x: x[1], reverse=True)

# %%
print(len(finder2.ngram_fd), len(finder3.ngram_fd))
count = 0
for k, v in combined:
    print(f"{k} - {v}")
    count += 1
    if count >= 10:
        break
# Out:
# 12752 5950
# ('Ku', 'Klux', 'Klan') - 32.47277595228941
# ('Child', 'Left', 'Behind') - 31.735810358123206
# ('Portland-Milwaukie', 'Light', 'Rail') - 31.32077285884436
# ('Minister', 'Benjamin', 'Netanyahu') - 31.320772858844357
# ('Prime', 'Minister', 'Benjamin') - 31.320772858844357
# ('Religious', 'Freedom', 'Restoration') - 31.05773845301057
# ('Rio', 'Grande', 'Valley') - 30.887813451568256
# ('Leticia', 'Van', 'de') - 30.05773845301057
# ('Van', 'de', 'Putte') - 30.05773845301057
# ('Catherine', 'Cortez', 'Masto') - 29.612953610337673

# %%
term_vector_base = [c[0] for c in combined[:top_n]]
vectors = custom_vectors_generation(texts, term_vector_base)

# %%
len(vectors[102])
# Out:
# 2001

# %%
min_score = 100
max_score = 0
n_2gram = 0
n_3gram = 0
for k, v in combined[:top_n]:
    min_score = min(min_score, v)
    max_score = max(max_score, v)
    
    if len(k) == 2:
        n_2gram += 1
    
    if len(k) == 3:
        n_3gram += 1
        
print(min_score)
print(max_score)
print(n_2gram)
print(n_3gram)
# Out:
# 12.886311945632038
# 32.47277595228941
# 304
# 1696

# %%
train_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'training'])
val_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'validation'])
test_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'testting'])

train_labels = np.array([labels[i] for i, d in data.iterrows() if d['tvt2'] == 'training'])
val_labels = np.array([labels[i] for i, d in data.iterrows() if d['tvt2'] == 'validation'])
test_labels = np.array([labels[i] for i, d in data.iterrows() if d['tvt2'] == 'testting'])

# %%
print(train_vectors.shape)
print(val_vectors.shape)
print(test_vectors.shape)

print(train_labels.shape)
print(val_labels.shape)
print(test_labels.shape)

train_vectors.mean(axis=0)
# Out:
# (8620, 2001)
# (2870, 2001)
# (1301, 2001)
# (8620,)
# (2870,)
# (1301,)
# array([1.16009281e-04, 3.48027842e-04, 3.48027842e-04, ...,
#        1.16009281e-04, 8.12064965e-04, 1.00000000e+00])

# %%
from sklearn.svm import LinearSVC

from library.classification import SKLearnClassification
from library.evaluation import ConfusionMatrix

svm = LinearSVC(multi_class="ovr", max_iter=10000)

model = SKLearnClassification(svm, "Support Vector Machine")
print(f"\n--- START ---")
model.train(train_vectors, train_labels, "LiarPantsFire")

print("Validation Set")
preds = model.predict(val_vectors)

conf_mat = ConfusionMatrix(
    labels=np.array([[1 if j == v else 0 for j in range(len(labels_str))] for v in val_labels]),
    predictions=np.array([[1 if j == p else 0 for j in range(len(labels_str))] for p in preds]),
    binary=False
)
conf_mat.evaluate(classes=labels_str)

print("--- END ---\n")
# Out:
# --- START ---
# ---> execution time : 0.32 seconds
# Validation Set
# 2870 vs 2870
# Multi Class Evaluation
#
# Class false Evaluation
# - Precision : 19.346 %
# - Recall : 64.87 %
# - F1 : 0.29804
#
# Class half-true Evaluation
# - Precision : 22.569 %
# - Recall : 11.304 %
# - F1 : 0.15064
#
# Class mostly-true Evaluation
# - Precision : 22.727 %
# - Recall : 12.774 %
# - F1 : 0.16355
#
# Class true Evaluation
# - Precision : 25.0 %
# - Recall : 7.782 %
# - F1 : 0.11869
#
# Class barely-true Evaluation
# - Precision : 21.03 %
# - Recall : 10.448 %
# - F1 : 0.1396
#
# Class pants-fire Evaluation
# - Precision : 23.377 %
# - Recall : 7.965 %
# - F1 : 0.11881
#
# Combined Evaluation
# - Accuracy : 20.592 %
# - Precision : 22.342 %
# - Recall : 19.19 %
# - F1 : 0.20646
#
# - Average Confidence : 100.0 %
# Model, Combined,,,,false,,,half-true,,,mostly-true,,,true,,,barely-true,,,pants-fire,,,
# Anonymous, 20.592, 22.342, 19.19, 0.20646, 19.346, 64.87, 0.29804, 22.569, 11.304, 0.15064, 22.727, 12.774, 0.16355, 25.0, 7.782, 0.11869, 21.03, 10.448, 0.1396, 23.377, 7.965, 0.11881,
# --- END ---

# %%
from scipy.sparse import csr_matrix

coefs = model.model.coef_
if type(coefs) == csr_matrix:
    coefs.toarray().tolist()[0]
else:
    coefs.tolist()
coefs_and_features = list(zip(coefs[0], term_vector_base))

# Most predictive overall
# coefs_and_features = sorted(coefs_and_features, key=lambda x: x[0], reverse=True)
coefs_and_features = sorted(coefs_and_features, key=lambda x: abs(x[0]), reverse=True)
print(f"Total tokens : {len(coefs_and_features)}")
# Out:
# Total tokens : 2000

# %%
coefs.shape
# Out:
# (6, 2001)

# %%
coefs_and_features
# Out:
# [(1.486268592731033, ('Attorney', 'General', 'Eric')),
#  (1.414297692532734, ('Supreme', 'Court', 'nominee')),
#  (1.4103088208769277, ('wildly', 'unpopular')),
#  (1.4089777018878118, ('Terry', 'McAuliffe')),
#  (1.4012763618629411, ('For', 'every', 'one')),
#  (1.3928195472247873, ('takeover', 'of', 'healthcare')),
#  (1.3721011660292852, ('babies', 'born', 'in')),
#  (1.3692931475036962, ('and', 'your', 'doctor')),
#  (1.3563602197005926, ('278,000', 'per', 'job')),
#  (1.3499320430781183, ('voted', 'six', 'times')),
#  (1.3113094503109817, ('Ted', 'Cruz', 'is')),
#  (1.3108328282994202, ('Sept', '11', '2001')),
#  (1.2958573295196896, ('talking', 'about', 'how')),
#  (1.2938145271514832, ('Dan', 'Branch')),
#  (-1.2879146957779373, ('turn', 'Medicare', 'into')),
#  (1.2780069366911997, ('Says', 'Ted', 'Strickland')),
#  (1.2780069353539512, ('Megyn', 'Kelly')),
#  (1.2780068848155206, ('biggest', 'tax', 'increase')),
#  (1.2686073537841924, ('socialized', 'medicine')),
#  (1.264859513657529, ('changed', 'his', 'position')),
#  (1.2476049845768356, ('Mitt', 'Romney', 'says')),
#  (1.242062514874076, ('to', 'Saudi', 'Arabia')),
#  (-1.239758640457041, ('parental', 'consent')),
#  (1.2146449950974563, ('Budget', 'Office', 'report')),
#  (1.2089869099197226, ('a', 'career', 'politician')),
#  (1.1788415987915037, ('attack', 'in', 'Benghazi')),
#  (1.1771116479199288, ('I', 'can', 'tell')),
#  (1.1736128106918096, ('print', 'ballots')),
#  (-1.1676005887147514, ('troops', 'in', 'Iraq')),
#  (1.165670469556663, ('Iraq', 'and', 'Syria')),
#  (1.1615925497637203, ('troops', 'from', 'Iraq')),
#  (1.1571478052519446, ('servicemen', 'and', 'women')),
#  (1.1434100682191732, ('aircraft', 'carriers')),
#  (1.1397755280630584, ('state', 'budget', 'includes')),
#  (1.1224820191833171, ('four', 'or', 'five')),
#  (1.1176018867594317, ('New', 'York', 'Times')),
#  (1.1118063117865429, ('Every', 'time', 'weve')),
#  (1.1117786697136967, ('weve', 'ever', 'had')),
#  (1.1033926627946844, ('office', 'in', 'January')),
#  (1.0803012780760612, ('made', 'it', 'easier')),
#  (1.0803012540273156, ('Ed', 'Gillespie')),
#  (-1.0726585148407746, ('Department', 'of', 'Veterans')),
#  (1.0720074843278296, ('a', 'nuclear', 'weapon')),
#  (1.0703356393756316, ('stand', 'your', 'ground')),
#  (-1.0654202515346025, ('health', 'care', 'system')),
#  (1.0653788749037727, ('could', 'be', 'used')),
#  (1.0650058507816982, ('U', 'S', 'citizenship')),
#  (1.0650058168146042, ('how', 'they', 'can')),
#  (1.0650057613198172, ('electric', 'utilities')),
#  (1.065005752377707, ('a', 'cap-and-trade', 'plan')),
#  (1.0650057453637045, ('the', 'Keystone', 'pipeline')),
#  (1.0650057452755102, ('raise', 'your', 'taxes')),
#  (1.0650057446925842, ('The', 'Iran', 'deal')),
#  (1.0650057417167644, ('150', 'a', 'month')),
#  (1.065005428342962, ('millionaires', 'and', 'billionaires')),
#  (1.0535370134659574, ('will', '...', 'force')),
#  (1.0432992810835344, ('Sen', 'John', 'McCain')),
#  (-1.0429537099733415, ('running', 'for', 'president')),
#  (-1.0367829659840884, ('health', 'insurance', 'premiums')),
#  (1.0340476111176526, ('Majority', 'Leader')),
#  (1.0219685738065045, ('When', 'Mitt', 'Romney')),
#  (-1.0210439589652862, ('Sen', 'Kay', 'Bailey')),
#  (1.0102640630590953, ('to', 'comply', 'with')),
#  (1.0093728967472257, ('Ponzi', 'scheme')),
#  (1.004683442610563, ('kidnapping', 'capital', 'of')),
#  (-0.9885284598329335, ('the', 'individual', 'mandate')),
#  (-0.9885283480291394, ('buy', 'a', 'gun')),
#  (0.9853725875728128, ('been', 'talking', 'about')),
#  (-0.982999220756515, ('Iran', 'nuclear', 'deal')),
#  (-0.9818850091972241, ('your', 'ground', 'law')),
#  (-0.9818848346170719, ('in', 'violent', 'crime')),
#  (-0.9759030491444911, ('make', 'sure', 'that')),
#  (0.964364349903394, ('Gov', 'Chris', 'Christies')),
#  (0.9581523601568185, ('On', 'Common', 'Core')),
#  (0.9551444103760506, ('per', 'capita', 'on')),
#  (-0.9548729328308936, ('before', 'I', 'became')),
#  (0.9543705432593276, ('Republican', 'or', 'Democrat')),
#  (0.9524261192751161, ('U', 'S', 'troops')),
#  (0.9441673630998658, ('the', 'voter', 'rolls')),
#  (0.9437624928534379, ('the', 'Second', 'Amendment')),
#  (0.9294426183510156, ('past', 'eight', 'years')),
#  (0.9283279747552705, ('voter', 'ID', 'law')),
#  (0.9242178716608959, ('since', 'Ive', 'been')),
#  (0.9242178588557999, ('Not', 'a', 'single')),
#  (-0.9241040508934439, ('You', 'might', 'be')),
#  (-0.9240840900693315, ('Says', 'Indiana', 'Gov')),
#  (-0.913261527868483, ('the', 'Super', 'Bowl')),
#  (0.9106526909940668, ('and', 'small', 'businesses')),
#  (0.9101107351403448, ('reached', 'its', 'highest')),
#  (0.9078955165688012, ('Social', 'Security', '...')),
#  (-0.9050902498982399, ('highest', 'per', 'capita')),
#  (0.9041901482708307, ('health', 'care', 'decisions')),
#  (-0.902038086673455, ('fiscal', 'cliff', 'deal')),
#  (0.9013906820038193, ('Rep', 'Debbie', 'Wasserman')),
#  (0.89983137925123, ('government-run', 'health', 'care')),
#  (-0.8993274467358064, ('before', 'Election', 'Day')),
#  (0.8923590244314366, ('sent', 'a', 'letter')),
#  (0.8919747135122453, ('under', 'FBI', 'investigation')),
#  (-0.8909997981820166, ('in', 'modern', 'history')),
#  (0.8870435011989328, ('President', 'Bill', 'Clinton')),
#  (0.8854362414961218, ('get', 'an', 'abortion')),
#  (-0.8844728226026396, ('Thats', 'a', 'fact')),
#  (-0.8844728140677589, ('path', 'to', 'citizenship')),
#  (-0.8844727996187755, ('coal-fired', 'power', 'plants')),
#  (-0.8844727645313458, ('Ive', 'been', 'governor')),
#  (-0.8844727634911743, ('of', 'National', 'Rifle')),
#  (-0.8844727533616331, ('Eric', 'Holders')),
#  (-0.884393576292336, ('a', 'government', 'takeover')),
#  (-0.8838054521932143, ('a', 'police', 'officer')),
#  (0.881370995860031, ('Under', 'Scott', 'Walker')),
#  (0.8802122711207047, ('Department', 'of', 'Transportation')),
#  (-0.8755638258789309, ('a', 'few', 'weeks')),
#  (-0.8714086291983741, ('Wall', 'Street', 'bailout')),
#  (0.868170057395075, ('Robert', 'Hurt')),
#  (-0.8627334341837134, ('would', 'lose', 'their')),
#  (-0.8624737952482561, ('amnesty', 'for', 'illegal')),
#  (-0.8618463692935044, ('last', 'three', 'months')),
#  (-0.8559080326016937, ('Scott', 'Walker', 'Wisconsin')),
#  (0.8539863796290427, ('officers', 'and', 'firefighters')),
#  (0.847163776275826, ('last', 'five', 'years')),
#  (0.8465462799967379, ('Congressman', 'Joe', 'Heck')),
#  (-0.8447516779257653, ('the', 'individual', 'market')),
#  (-0.8320627360797316, ('Mitt', 'Romney', 'was')),
#  (0.8306886023256047, ('when', 'Mitt', 'Romney')),
#  (-0.8305059298368056, ('every', 'dollar', 'we')),
#  (0.8223504542334981, ('bin', 'Laden')),
#  (0.8192672843141846, ('Gov', 'Nathan', 'Deal')),
#  (0.816502249104771, ('companies', 'that', 'ship')),
#  (0.812692303127428, ('budget', 'repair', 'bill')),
#  (0.8116847567033312, ('Republican', 'Senate', 'candidate')),
#  (-0.8104298314823021, ('Hillary', 'Clinton', 'said')),
#  (-0.8095277452871903, ('Sen', 'Bill', 'Nelson')),
#  (0.8088809244631698, ('King', 'Jr', 'was')),
#  (0.8084643533939406, ('Lamar', 'Smith')),
#  (-0.800453028757393, ('We', 'havent', 'had')),
#  (-0.800453012560217, ('Frank', 'Guinta')),
#  (-0.8004529722652824, ('since', 'the', '1920s')),
#  (-0.8004529717277772, ('smaller', 'and', 'smaller')),
#  (-0.8004529537659956, ('for', 'Medicaid', 'expansion')),
#  (-0.8000633298652309, ('Scott', 'Walkers', 'proposed')),
#  (0.7998280243285312, ('to', 'House', 'Speaker')),
#  (0.7994463670825672, ('Sen', 'Barbara', 'Boxer')),
#  (0.7981881671549073, ('past', '20', 'years')),
#  (0.7981881083645072, ('grocery', 'stores')),
#  (0.7981881017059588, ('sea-level', 'rise')),
#  (0.7981880712128087, ('Carol', 'Shea-Porter')),
#  (0.7981880465399899, ('Medicaid', 'expansion', 'is')),
#  (0.7978646013242409, ('birther', 'movement')),
#  (0.7978645766733153, ('some', 'kind', 'of')),
#  (0.7978645667999089, ('a', 'little', 'bit')),
#  (0.797864544701007, ('The', 'Islamic', 'State')),
#  (0.7978645267169683, ('General', 'Motors', 'is')),
#  (0.7978645249724554, ('Export-Import', 'Bank')),
#  (0.7978644568305434, ('Bruce', 'Starr')),
#  (0.7881705925410663, ('For', 'every', 'dollar')),
#  (0.7870643694102979, ('of', 'jail', 'free')),
#  (-0.7824826879637992, ('Since', 'President', 'Obama')),
#  (0.7788954032412382, ('Scott', 'Walkers', 'budget')),
#  (-0.7764913407331164, ('on', 'job', 'creation')),
#  (-0.7755891695235091, ('rainy', 'day', 'fund')),
#  (0.7731511093927357, ('few', 'weeks', 'ago')),
#  (-0.7724078580859886, ('Over', 'the', 'past')),
#  (-0.7702603552272002, ('El', 'Paso')),
#  (0.7700343131696231, ('Says', 'Rob', 'Portman')),
#  (-0.7695492554797387, ('with', 'Nancy', 'Pelosi')),
#  (0.7685294324872389, ('at', 'least', 'one')),
#  (0.7657059801042789, ('Indiana', 'Gov', 'Mike')),
#  (0.7656600518279842, ('pay', 'no', 'income')),
#  (0.7656208393948549, ('Dennis', 'Kucinich')),
#  (-0.7653461495624022, ('privatizing', 'Social', 'Security')),
#  (0.765229552563392, ('Election', 'Day')),
#  (-0.7649984587373864, ('Abraham', 'Lincoln')),
#  (-0.7647973326714198, ('only', 'candidate', 'who')),
#  (-0.7646939696764197, ('paid', 'family', 'leave')),
#  (0.7632786614209797, ('prescription', 'drug', 'program')),
#  (0.7631045393867367, ('the', 'terrorist', 'attacks')),
#  (-0.7628145308475232, ('Says', 'Jeanne', 'Shaheen')),
#  (0.7622455421044156, ('Bob', 'McDonnell')),
#  (-0.761051353134735, ('of', 'domestic', 'violence')),
#  (-0.7576161336592702, ('tens', 'of', 'thousands')),
#  (-0.7547231116713587, ('Puerto', 'Ricos')),
#  (-0.7513661229065912, ('Says', 'Debbie', 'Wasserman')),
#  (0.7505464950236294, ('side', 'by', 'side')),
#  (-0.7503293399054721, ('the', 'middle', 'class')),
#  (0.7476550200324066, ('will', 'lose', 'their')),
#  (0.74671468865276, ('I', 'became', 'governor')),
#  (0.7466190160119309, ('global', 'warming', 'is')),
#  (0.7450063329811667, ('the', 'Civil', 'War')),
#  (0.744587504951939, ('Saddam', 'Hussein', 'had')),
#  (0.7445496880582364, ('In', 'North', 'Carolina')),
#  (0.739704801285513, ('to', 'make', 'sure')),
#  (0.7396613203315501, ('Donald', 'Trump', 'doesnt')),
#  (0.7390857442995573, ('Super', 'Bowl')),
#  (0.7371141503965966, ('Hillary', 'Clinton', 'wants')),
#  (-0.736764228712979, ('privatize', 'Social', 'Security')),
#  (0.7361851656072285, ('so', 'far', 'from')),
#  (0.7349062402927292, ('Tammy', 'Baldwin', 'voted')),
#  (-0.7333770853602709, ('Jack', 'Kingston', 'voted')),
#  (0.7329803873679428, ('Jimmy', 'Carter')),
#  (0.7295932401822897, ('of', 'Wall', 'Street')),
#  (-0.726179735583273, ('Sen', 'Ron', 'Johnson')),
#  (-0.726179735583273, ('S', 'Sen', 'Ron')),
#  (0.7250564159529738, ('The', 'fiscal', 'cliff')),
#  (-0.723033691112821, ('Americans', 'have', 'died')),
#  (-0.7205004597658609, ('vast', 'majority', 'of')),
#  (0.7175179930715359, ('goes', 'into', 'effect')),
#  (-0.7156390841794212, ('Rick', 'Scott', 'cut')),
#  (-0.711843481891523, ('750,000', 'jobs', 'a')),
#  (0.7112584738021255, ('president', 'in', 'modern')),
#  (-0.7111114243168416, ('every', 'single', 'day')),
#  (0.7100037702707415, ('the', 'Secret', 'Service')),
#  (0.7100037702707415, ('Secret', 'Service')),
#  (-0.7089150005413637, ('of', 'Homeland', 'Security')),
#  (0.7086332970817, ('if', 'we', 'do')),
#  (-0.7059257714005241, ('taxes', 'and', 'fees')),
#  (-0.7045540657250228, ('health', 'insurance', 'companies')),
#  (-0.7043365153443591, ('breaks', 'for', 'companies')),
#  (-0.7043365153443591, ('that', 'ship', 'jobs')),
#  (-0.703728102297273, ('More', 'than', 'half')),
#  (-0.7009267102263506, ('Air', 'Force', 'One')),
#  (-0.691296254957956, ('a', 'spending', 'spree')),
#  (0.69036977654531, ('Says', 'Ken', 'Cuccinelli')),
#  (0.6899204756362225, ('Brendan', 'Doherty')),
#  (0.6876472626584391, ('dont', 'know', 'who')),
#  (-0.6818065084655478, ('for', 'undocumented', 'immigrants')),
#  (-0.6796656110935753, ('you', 'know', 'how')),
#  (0.6789786909331997, ('S', 'House', 'candidate')),
#  (-0.6789299689359664, ('federal', 'stimulus', 'program')),
#  (0.6771659169639153, ('Bill', 'Nelson', 'voted')),
#  (-0.6768774450996219, ('take', 'the', 'SAT')),
#  (0.6766675478610112, ('Says', 'Daniel', 'Webster')),
#  (-0.6752090898632597, ('Government', 'Accountability', 'Office')),
#  (-0.6752090898632596, ('full', 'control', 'of')),
#  (-0.6722039056999516, ('job', 'training', 'programs')),
#  (-0.672179653633975, ('When', 'Social', 'Security')),
#  (-0.6705986189891944, ('the', 'financial', 'crisis')),
#  (-0.667193269852767, ('Says', 'Paul', 'Ryan')),
#  (-0.6670131458902762, ('Trumps', 'tax', 'plan')),
#  (0.6652737367254291, ('we', 'were', 'losing')),
#  (0.6641758093425771, ('lose', 'their', 'health')),
#  (-0.6629668322750861, ('presidents', 'health', 'care')),
#  (-0.6622002896784096, ('the', 'vast', 'majority')),
#  (0.6617254904707212, ('Mary', 'Burke', 'was')),
#  (-0.6612350930757667, ('money', 'from', 'Wall')),
#  (0.6611290925268742, ('kicked', 'out', 'of')),
#  (0.6563972533077558, ('Rob', 'Cornilles')),
#  (-0.6556981604243091, ('Board', 'of', 'Education')),
#  (0.6543397216847469, ('how', 'much', 'money')),
#  (0.6541537655366608, ('the', 'Border', 'Patrol')),
#  (-0.6531844737684315, ('doesnt', 'believe', 'in')),
#  (0.6531007468160481, ('to', 'illegal', 'aliens')),
#  (0.6523092101911903, ('Jack', 'Kingston')),
#  (-0.6521448127692623, ('in', 'real', 'terms')),
#  (-0.6497541933607212, ('labor', 'force', 'participation')),
#  (-0.6493121687226825, ('U', 'S', 'Department')),
#  (0.6488043124543933, ('police', 'officers', 'and')),
#  (-0.6487966365039144, ('Wall', 'Street', 'than')),
#  (0.6484546351379161, ('of', 'St', 'Petersburg')),
#  (-0.647599402471756, ('on', 'climate', 'change')),
#  (-0.6445848308921871, ('among', 'other', 'things')),
#  (-0.6445846510617425, ('Mary', 'Landrieu')),
#  (-0.6434126300618205, ('Harry', 'Reid', 'has')),
#  (0.6427271979843849, ('Rep', 'Paul', 'Ryan')),
#  (0.6427271979843849, ('by', 'Rep', 'Paul')),
#  (0.6412808735652064, ('Mary', 'Burkes')),
#  (0.6410405501729337, ('the', 'General', 'Assembly')),
#  (0.6390034806649064, ('Midwest', 'job', 'growth')),
#  (0.6390034806649064, ('in', 'Midwest', 'job')),
#  (0.6390034639235622, ('of', 'Labor', 'Statistics')),
#  (0.6390034639235622, ('Bureau', 'of', 'Labor')),
#  (-0.6364675853804708, ('Koch', 'Industries')),
#  (0.6358673015451195, ('Scott', 'Walker', 'took')),
#  (-0.635841090093387, ('for', 'high-speed', 'rail')),
#  (-0.6346956918174946, ('Mitt', 'Romney', 'said')),
#  (0.6344531272667046, ('Rob', 'Portmans')),
#  (0.6341391920122178, ('the', '38', 'Studios')),
#  (-0.6336891688842292, ('price', 'tag')),
#  (-0.6287859997138315, ('have', 'been', 'confirmed')),
#  (0.6251360565583635, ('cap', 'and', 'trade')),
#  (0.620650466609374, ('town', 'hall', 'meeting')),
#  (-0.6200229577428864, ('high', 'school', 'students')),
#  (-0.6144901074583037, ('Budget', 'Office', 'estimates')),
#  (0.6143836554132038, ('any', 'other', 'place')),
#  (0.6135658597474265, ('city', 'of', 'St')),
#  (0.612824803430453, ('Do', 'you', 'know')),
#  (-0.6109280550571105, ('undocumented', 'immigrants', 'and')),
#  (0.6109269015540805, ('the', 'Internal', 'Revenue')),
#  (0.6104327185372393, ('Milwaukee', 'County', 'Executive')),
#  (0.6097611751611662, ('the', 'attorney', 'general')),
#  (-0.6082896071031857, ('the', 'National', 'Guard')),
#  (-0.6057080850198623, ('hours', 'of', 'early')),
#  (-0.6057080850198623, ('of', 'early', 'voting')),
#  (-0.6054897542040911, ('would', 'turn', 'Medicare')),
#  (0.6051252738900215, ('my', 'home', 'state')),
#  (-0.603786121186393, ('Adam', 'Hasner')),
#  (-0.603785244382206, ('Cory', 'Gardner')),
#  (-0.60378316648795, ('his', 'tax', 'returns')),
#  (0.6034068771340971, ('Says', 'Donald', 'Trumps')),
#  (-0.6029084108674835, ('signed', 'into', 'law')),
#  (-0.6015668937008675, ('dont', 'know', 'where')),
#  (-0.6015668165213637, ('twice', 'as', 'many')),
#  (-0.598028714844543, ('Care', 'Act', 'is')),
#  (0.5973620696609572, ('government', 'takeover', 'of')),
#  (-0.5960541395763068, ('Richard', 'Burr')),
#  (-0.5933001375367272, ('Al', 'Franken')),
#  (0.5928195634162474, ('for', 'current', 'retirees')),
#  (0.5915365829553587, ('Ron', 'Johnson', 'is')),
#  (-0.5905069944713072, ('Barack', "Obama's", 'health')),
#  (0.5897646776259946, ('Ryans', 'budget', 'proposal')),
#  (0.5889693583274289, ('the', 'United', 'Nations')),
#  (-0.5879870808955178, ('Ed', 'Gillespies')),
#  (-0.5814469150812943, ('Common', 'Core', 'standards')),
#  (0.5798291222699847, ('deciding', 'vote', 'on')),
#  (-0.5794822057376496, ('and', 'guess', 'what')),
#  (0.5785338172681767, ('since', 'Dwight', 'Eisenhower')),
#  (0.5785338172681767, ('Dwight', 'Eisenhower', 'was')),
#  (0.5785338172681767, ('Eisenhower', 'was', 'president')),
#  (0.5757275742713499, ('The', 'minimum', 'wage')),
#  (-0.5756641639274354, ('insurance', 'companies', 'deny')),
#  (0.5756163173179211, ('this', 'countrys', 'history')),
#  (-0.5729723661882655, ('will', 'be', 'forced')),
#  (0.5721012238522185, ('expected', 'to', 'create')),
#  (0.5714653985386984, ('highest', 'crime', 'rates')),
#  (0.5643856282789695, ('for', 'illegal', 'immigrants')),
#  (-0.5632991470056924, ('Sen', 'Rob', 'Portman')),
#  (0.5626267525460172, ('Social', 'Security', 'benefits')),
#  (-0.5616043609409186, ('debt', 'ceiling', 'deal')),
#  (0.5611980210428658, ('Supreme', 'Court', 'justices')),
#  (-0.5566777370442613, ('I', 'took', 'office')),
#  (-0.5544382054703445, ('collective', 'bargaining', 'rights')),
#  (0.5525259765573103, ('are', 'exempt', 'from')),
#  (0.5491514421786455, ('Ron', 'Johnson', 'voted')),
#  (0.5470021379056247, ('minimum', 'wage', 'are')),
#  (-0.5462689735658732, ('As', 'a', 'result')),
#  (-0.5462689537084292, ('a', 'convicted', 'felon')),
#  (-0.545612345127314, ('world', 'right', 'now')),
#  (0.541847608574532, ('ship', 'jobs', 'overseas')),
#  (0.5385377061514055, ('destabilize', 'the', 'Middle')),
#  (-0.5385014889749536, ('a', 'constitutional', 'right')),
#  (-0.5385014889749534, ('No', 'other', 'country')),
#  (-0.5379934098935513, ('Barack', 'Obamas', 'watch')),
#  (0.5376592247291219, ('Senate', 'version', 'of')),
#  (0.5359660186357463, ('the', 'Keystone', 'XL')),
#  (-0.5357839544762178, ('his', 'first', 'term')),
#  (-0.5353564237491241, ('voter', 'fraud', 'in')),
#  (0.5343751999945041, ('Says', 'Gov', 'Scott')),
#  (-0.5338870077137337, ('former', 'President', 'Bill')),
#  (0.5311189094758817, ('in', 'North', 'Carolina')),
#  (0.5311187717798178, ('Declaration', 'of', 'Independence')),
#  (-0.5299601084446929, ('Gina', 'Raimondo')),
#  (0.5280124735631235, ('U', 'S', 'senator')),
#  (0.5258968240369806, ('first', 'time', 'since')),
#  (0.5256124742303447, ('senior', 'citizens', 'who')),
#  (-0.5246947916984671, ('spending', 'went', 'up')),
#  (-0.5246945219360928, ('Countys', 'unemployment', 'rate')),
#  (-0.5233163816163666, ('almost', 'as', 'much')),
#  (-0.5218262194884097, ('with', 'John', 'McCain')),
#  (-0.5209489194866942, ('Trans-Pacific', 'Partnership', 'and')),
#  (-0.5207046075401256, ('a', 'background', 'check')),
#  (-0.519899610934003, ('cut', 'Social', 'Security')),
#  (0.5198093956576657, ('the', 'Wall', 'Street')),
#  (-0.5185614716579799, ('K', '12', 'funding')),
#  (-0.5179403610361226, ('businesses', 'have', 'created')),
#  (-0.517940245069724, ('cracking', 'down', 'on')),
#  (-0.5179402057074354, ('middle', 'class', 'families')),
#  (-0.51794017270736, ('Palm', 'Beach')),
#  (-0.5179401657365595, ('Austin', 'City', 'Council')),
#  (-0.5179401572885659, ('Milwaukee', 'County', 'executive')),
#  (-0.5179401562884375, ('Democratic', 'recall', 'opponent')),
#  (-0.5179401562884375, ('Says', 'Democratic', 'recall')),
#  (-0.5179401538720109, ('looking', 'for', 'work')),
#  (-0.5179401511168372, ('Democrat', 'or', 'Republican')),
#  (0.5175783457236867, ('health', 'care', 'overhaul')),
#  (0.5152708493234476, ('jobs', 'per', 'month')),
#  (0.5139397948670928, ('Court', 'of', 'Appeals')),
#  (0.5138432988795527, ('Marco', 'Rubio', 'said')),
#  (-0.5130082611461931, ('first', 'Gulf', 'War')),
#  (0.5114854926802852, ('the', 'campaign', 'trail')),
#  (0.5113197086678963, ('the', 'Common', 'Core')),
#  (0.5111993504555807, ('Scott', 'Walker', 'is')),
#  (0.5099429090024971, ('Gov', 'Rick', 'Scott')),
#  (0.5085679672996299, ('raises', 'taxes', 'on')),
#  (-0.5084871455069204, ('Reagan', 'took', 'office')),
#  (0.5081399874505383, ('Donald', 'Trump', 'promised')),
#  (0.5079913735657613, ('twice', 'as', 'much')),
#  (0.5068285723570403, ('minimum', 'wage', 'workers')),
#  (0.506575212549596, ('has', 'gone', 'down')),
#  (-0.5063015409353805, ('Sherrod', 'Brown', 'has')),
#  (-0.5063015409353803, ('the', 'modern', 'era')),
#  (-0.5047130200354215, ('candidate', 'Jack', 'Kingston')),
#  (-0.5047130200354215, ('Senate', 'candidate', 'Jack')),
#  (0.5029864499975765, ('Says', 'Mitch', 'McConnell')),
#  (0.5029205658651834, ('I', 'dont', 'think')),
#  (-0.5025332113155114, ('Osama', 'bin', 'Laden')),
#  (-0.5025332113155114, ('Osama', 'bin')),
#  (-0.5006288980906486, ('will', 'no', 'longer')),
#  (0.4998589873582471, ('Border', 'Patrol')),
#  (-0.49883715348716773, ('build', 'a', 'wall')),
#  (0.4984160902191812, ('Common', 'Core', 'is')),
#  (0.49589262817108637, ('men', 'and', 'women')),
#  (0.4948741765212681, ('most', 'generous', 'in')),
#  (0.493723973885526, ('Rhode', 'Island', 'is')),
#  (0.48745896055697685, ('Jeanne', 'Shaheen')),
#  (0.48696596533303504, ('the', 'capital', 'gains')),
#  (-0.486943248690324, ('has', 'grown', 'by')),
#  (-0.48637580708736433, ('New', 'Hampshire', 'has')),
#  (-0.4858895769335416, ('Russia', 'and', 'China')),
#  (0.4842430703393652, ('the', 'gold', 'standard')),
#  (0.4832690299479528, ('health', 'care', 'costs')),
#  (-0.4809277538414475, ('Speaker', 'Joe', 'Straus')),
#  (-0.4809277538414475, ('House', 'Speaker', 'Joe')),
#  (0.47948906077903375, ('health', 'care', 'mandate')),
#  (-0.4780884183953045, ('will', 'see', 'their')),
#  (0.4780076127307624, ('congressional', 'district', 'has')),
#  (0.47800749148929556, ('Jeb', 'Bush', 'was')),
#  (0.47800714943999467, ('Lee', 'Fisher')),
#  (0.47800708391886026, ('Department', 'of', 'Agriculture')),
#  (0.4780070081214026, ('on', 'this', 'issue')),
#  (0.47800695408599303, ('light', 'bulb')),
#  (0.47800693235935654, ('the', 'highest', 'taxed')),
#  (0.47800693223981794, ('Kathryn', 'Starkey')),
#  (0.4780069320919216, ('have', 'repeatedly', 'said')),
#  (0.4780069239626157, ('spends', 'more', 'money')),
#  (0.47800691806006534, ('al', 'Qaeda')),
#  (0.47800691794466754, ('trying', 'to', 'find')),
#  (0.47800691755578195, ('at', 'least', '15')),
#  (0.4780069118154038, ('collective', 'bargaining', 'for')),
#  (0.4780069004456595, ('of', 'renewable', 'energy')),
#  (0.47800689844340716, ('law', 'enforcement', 'agencies')),
#  (0.4780068967361921, ('other', 'states', 'combined')),
#  (0.4780068908476244, ('mentally', 'ill')),
#  (0.47800688837820693, ('Illegal', 'immigration', 'costs')),
#  (0.478006887878464, ('Republicans', 'took', 'over')),
#  (0.47800688203086406, ('Ann', 'Kuster')),
#  (0.4780068588064339, ('Jason', 'Carter')),
#  (0.478006843314144, ('can', 'be', 'used')),
#  (0.47800681714752713, ('Harry', 'Reids')),
#  (0.47800678554575804, ('war', 'on', 'coal')),
#  (0.47800673720711095, ('five', 'years', 'ago')),
#  (0.4777314013516287, ('Says', 'Tammy', 'Baldwin')),
#  (0.47362197579406795, ('fluorescent', 'light', 'bulbs')),
#  (-0.47177859627414503, ('Elena', 'Kagan')),
#  (-0.47173303729901395, ('conflict', 'of', 'interest')),
#  (-0.4717329950520359, ('economic', 'stimulus', 'plan')),
#  (0.4716566987568307, ('high-speed', 'rail')),
#  (-0.4716098901162485, ('ago', 'John', 'McCain')),
#  (0.47032218772032175, ('per', 'capita', 'in')),
#  (0.4697720504713351, ('has', 'never', 'received')),
#  (-0.4692546586827619, ('Jon', 'Corzine')),
#  (0.46860732929504334, ('salary', 'and', 'benefits')),
#  (-0.4672605361161664, ('the', 'Soviet', 'Union')),
#  (-0.46700777911876035, ('D', 'C', 'area')),
#  (0.4667319076031261, ('income', 'tax', 'rates')),
#  (0.46594831314353513, ('small', 'business', 'owners')),
#  (0.46515464058274136, ('by', 'Planned', 'Parenthood')),
#  (0.4647779833522486, ('Patrick', 'Murphy', 'is')),
#  (-0.4646845957994496, ('its', 'highest', 'level')),
#  (0.46367688881057634, ('a', 'sanctuary', 'city')),
#  (-0.46229478199087065, ('on', 'campaign', 'finance')),
#  (-0.4621768470306951, ('and', 'police', 'officers')),
#  (-0.46217684703069506, ('to', 'lay', 'off')),
#  (0.46210890878445626, ('National', 'Rifle', 'Association')),
#  (0.46210890878445626, ('Rifle', 'Association')),
#  (0.46210890021438633, ('Clean', 'Power', 'Plan')),
#  (0.46210890021438633, ('Clean', 'Power')),
#  (0.4610048506373602, ('Josh', 'Mandel')),
#  (0.46032235182782333, ('Margaret', 'Sanger')),
#  (-0.4597592975997811, ('Edward', 'Snowden')),
#  (0.45942411331972455, ('Under', 'President', 'Barack')),
#  (0.45843879284145617, ('Says', 'Patrick', 'Murphy')),
#  (0.457987337539256, ('drivers', 'licenses', 'to')),
#  (0.4562789204534614, ('when', 'he', 'ran')),
#  (-0.4555970606132537, ('Health', 'Insurance', 'Program')),
#  (0.45522589692745785, ('public', 'school', 'teachers')),
#  (-0.45418869474153306, ('Ronald', 'Reagan', 'was')),
#  (-0.45418869474153295, ('Says', 'Ronald', 'Reagan')),
#  (-0.4540634315626797, ('almost', '50', 'percent')),
#  (0.4505013361251627, ('Lloyd', 'Doggett')),
#  (-0.45031580389512804, ('Voting', 'Rights', 'Act')),
#  (-0.45031580389512804, ('Voting', 'Rights')),
#  (-0.45031580389512804, ('40', 'years', 'ago')),
#  (0.44965979061245875, ('Sonia', 'Sotomayor')),
#  (0.4489111294331556, ('The', 'Congressional', 'Budget')),
#  (-0.4484901605785856, ('Wisconsin', 'Supreme', 'Court')),
#  (-0.4484901605785856, ('very', 'similar', 'to')),
#  (-0.44849016057858554, ('Bernie', 'Sanders', 'was')),
#  (-0.44643583356841227, ('minimum', 'wage', 'is')),
#  (-0.4430875266138249, ('it', 'harder', 'for')),
#  (0.44245729902081243, ('Rob', 'Portman')),
#  (0.44040831282524273, ('since', 'World', 'War')),
#  (-0.4403767013438741, ('in', 'campaign', 'contributions')),
#  (0.4401178204785821, ('since', 'hes', 'been')),
#  (0.439333170126182, ('Chris', 'Christie', 'was')),
#  (0.43742376128114646, ('off', 'Virginias', 'coast')),
#  (-0.4368690924943018, ('Nathan', 'Deal')),
#  (-0.4362204745337867, ('eight', 'years', 'under')),
#  (0.4329903399038317, ('S', 'Senate', 'candidate')),
#  (0.4325690247715702, ('Says', 'Ron', 'Johnson')),
#  (-0.4309054948544708, ('its', 'ever', 'been')),
#  (0.42996673985521205, ('past', 'five', 'years')),
#  (-0.42970284345168935, ('school', 'choice', 'program')),
#  (0.42961936909813647, ('for', 'gay', 'marriage')),
#  (0.42961936909813647, ('support', 'for', 'gay')),
#  (-0.429352420030826, ('some', 'form', 'of')),
#  (0.42544208362426594, ('the', 'stock', 'market')),
#  (0.4244717732095152, ('of', 'Veterans', 'Affairs')),
#  (0.4244717732095152, ('Veterans', 'Affairs')),
#  (0.42276104963123967, ('without', 'health', 'insurance')),
#  (0.42251789294557773, ('Alan', 'Grayson')),
#  (0.41966525074141914, ('get', 'Social', 'Security')),
#  (0.4196571557533557, ('Supreme', 'Court', 'justice')),
#  (-0.4194241114167741, ('rival', 'Tammy', 'Baldwin')),
#  (-0.4194241114167741, ('Senate', 'rival', 'Tammy')),
#  (0.41872015439914345, ('Paul', 'Ryan', 'budget')),
#  (-0.41836410258782586, ('at', 'any', 'time')),
#  (0.4181611490586562, ('Newt', 'Gingrich', 'has')),
#  (-0.4176710166928292, ('Supreme', 'Court', 'has')),
#  (-0.417671016692829, ('more', 'than', '4,000')),
#  (0.4170622515270104, ('Paul', 'Ryan', 'is')),
#  (0.41694808007711753, ('Barack', 'Obamas', 'health')),
#  (0.41691213277456235, ('you', 'can', 'get')),
#  (0.4159270244369289, ('corporate', 'income', 'tax')),
#  (0.41584187955994706, ('Luther', 'King', 'Jr')),
#  (0.413056107249687, ('refused', 'to', 'say')),
#  (0.4120787041834825, ('Justice', 'Rebecca', 'Bradley')),
#  (0.4120787041834825, ('Rebecca', 'Bradley')),
#  (-0.4096902921376806, ('we', 'do', 'nothing')),
#  (-0.40925671129576835, ('town', 'hall', 'meetings')),
#  (-0.40858126167146325, ('does', 'better', 'when')),
#  (0.4076942990019815, ('Executive', 'Chris', 'Abele')),
#  (0.4071773461671339, ('any', 'other', 'member')),
#  (0.40573938473157267, ('Mickey', 'Mouse')),
#  (-0.4023227790956933, ('to', 'Wall', 'Street')),
#  (-0.4019940326478772, ('More', 'than', '80')),
#  (-0.4019857105020079, ('supports', 'privatizing', 'Social')),
#  (-0.4017980984210135, ('said', 'we', 'should')),
#  (0.40118458262308976, ('Barack', 'Obama', 'promised')),
#  (-0.39934061307528274, ('McCain', 'voted', 'against')),
#  (-0.3989555882123134, ('the', 'DREAM', 'Act')),
#  (0.3986957041698122, ('Jason', 'Kander')),
#  (-0.3986948376954408, ('city', 'of', 'Atlanta')),
#  (-0.3970087759339055, ('No', '1', 'cause')),
#  (-0.39440337082266713, ('a', 'Supreme', 'Court')),
#  (-0.3942196582300437, ('sanctuary', 'cities', 'in')),
#  (-0.3930390449032227, ('John', 'McCain', 'voted')),
#  (0.3924487583031131, ('have', 'gone', 'up')),
#  (-0.3923123544137224, ('fuel', 'efficiency', 'standards')),
#  (-0.3915909789816158, ('The', 'Republican', 'Party')),
#  (-0.39145914540465954, ('what', 'they', 'spend')),
#  (-0.39110137480995566, ('U', 'S', 'cities')),
#  (-0.39037592443070857, ('Eric', 'Hovde')),
#  (-0.3901375906188661, ('the', 'fastest', 'growing')),
#  (-0.390137518393878, ('Creflo', 'Dollar')),
#  (-0.3892835200374222, ('know', 'how', 'much')),
#  (0.3880734462065258, ('Bridge', 'to', 'Nowhere')),
#  (0.3868943769535225, ('Bush-era', 'tax', 'cuts')),
#  (-0.38684162456526705, ('If', 'you', 'look')),
#  (0.38455048960901017, ('last', 'two', 'years')),
#  (0.38381502050590366, ('Mae', 'and', 'Freddie')),
#  (0.38381502050590366, ('and', 'Freddie', 'Mac')),
#  (-0.38350904383383616, ('wants', 'to', 'eliminate')),
#  (-0.38286120770881055, ('Patrick', 'Murphy', 'voted')),
#  (0.3824831603129613, ('as', 'much', 'as')),
#  (0.3822989638936275, ('Gov', 'Scott', 'Walkers')),
#  (0.38206086896045954, ('Scott', 'Walker', 'cut')),
#  (-0.3813365688648997, ('Senate', 'Majority', 'Leader')),
#  (-0.3807805446768282, ('Tom', 'Barrett', 'voted')),
#  (-0.3806338220568107, ('employers', 'should', 'be')),
#  (0.3802482241536442, ('war', 'in', 'Iraq')),
#  (0.37972807591229457, ('rival', 'Tommy', 'Thompson')),
#  (0.37972807591229457, ('Senate', 'rival', 'Tommy')),
#  (0.3793950527364356, ('of', 'voter', 'fraud')),
#  (-0.3791975500682958, ('Says', 'Sen', 'Sherrod')),
#  (-0.37830976430853785, ('Gov', 'Jim', 'Doyle')),
#  (-0.37815040202824757, ('S', 'Senate', 'race')),
#  (-0.3776659779024046, ('mental', 'health', 'services')),
#  (-0.37663731520365634, ('with', 'George', 'Bush')),
#  (0.376497914597026, ('Thomas', 'Jefferson')),
#  (-0.3756586315143172, ('has', 'gone', 'up')),
#  (-0.3755028587749012, ('South', 'Carolina', 'has')),
#  (0.37535079731553334, ('times', 'faster', 'than')),
#  (-0.37520973885254105, ('middle', 'class', 'and')),
#  (0.3750073354497509, ('the', 'private', 'sector')),
#  (-0.3749475039293166, ('private', 'sector', 'jobs')),
#  (0.37441897129596513, ('massive', 'tax', 'increase')),
#  (0.37441896276538034, ('with', 'their', 'parents')),
#  (0.37441894159995415, ('registered', 'voters', 'in')),
#  (0.37441892669195115, ('The', 'Milwaukee', 'County')),
#  (0.37441889979444193, ('will', 'kill', 'jobs')),
#  (0.3744188951457727, ('Wall', 'Street', 'banks')),
#  (0.37441888770630377, ('p', 'm')),
#  (0.37441885295630517, ('Obamacare', 'became', 'law')),
#  (-0.37290247353793216, ('Rev', 'Wright')),
#  (-0.3722937964277739, ('Republican', 'presidential', 'candidates')),
#  (-0.3718167067937258, ('Chris', 'Christie', 'has')),
#  (-0.37084686727845073, ('same', 'type', 'of')),
#  (-0.37084686727845073, ('the', 'same', 'type')),
#  (-0.3705271034893782, ('any', 'other', 'country')),
#  (-0.37017375257487634, ('colleges', 'and', 'universities')),
#  (-0.36931562246435007, ('billion', 'budget', 'deficit')),
#  (-0.3690849363329537, ('an', 'individual', 'mandate')),
#  (-0.3684249830440666, ('without', 'raising', 'taxes')),
#  (-0.36819836363847036, ('Alex', 'Sink')),
#  (0.3677933151219968, ('Says', 'Newt', 'Gingrich')),
#  (-0.36707950347004265, ('he', 'took', 'office')),
#  (-0.36707948619425584, ('the', 'Union', 'address')),
#  (-0.3670794718890079, ('last', 'six', 'months')),
#  (-0.3669799570115141, ('Michelle', 'Nunn')),
#  (-0.36691353950346983, ('less', 'popular', 'than')),
#  (-0.36618885178603394, ('net', 'worth', 'of')),
#  (-0.3661887753011305, ('law', 'enforcement', 'officers')),
#  (-0.3659012854988498, ('Donald', 'Trump', 'has')),
#  (-0.3650478343050293, ('Says', 'David', 'Dewhurst')),
#  (0.36409699395690664, ('to', 'expand', 'Medicaid')),
#  (-0.36407918574657644, ('for', 'every', 'dollar')),
#  (-0.36336043906039434, ('know', 'where', 'he')),
#  (-0.3632137293743143, ('troops', 'in', 'Afghanistan')),
#  (-0.3629919789889753, ('universal', 'health', 'care')),
#  (-0.3625792904180427, ('2001', 'and', '2003')),
#  (-0.362565037747104, ('the', 'poverty', 'line')),
#  (-0.3625650272247243, ('Rick', 'Perrys', 'watch')),
#  (0.362218932818426, ('Steve', 'Southerland')),
#  (-0.3621326628482878, ('401', 'k')),
#  (-0.3620944069525966, ('Mitt', 'Romney', 'wants')),
#  (-0.3608162453287943, ('last', 'seven', 'years')),
#  (-0.36075005635899093, ('Says', 'Rick', 'Santorum')),
#  (-0.3604039270175399, ('live', 'in', 'poverty')),
#  (0.36018837029642314, ('Sen', 'Sherrod', 'Brown')),
#  (-0.35965722645359505, ('Sarah', 'Palin', 'was')),
#  (-0.35835497951658346, ('the', 'African-American', 'community')),
#  (-0.3583548569434712, ('Charlie', 'Crist', 'signed')),
#  (-0.3582626911575096, ('not', 'be', 'able')),
#  (-0.3577703137687784, ('Vladimir', 'Putin')),
#  (-0.3577701176244169, ('twice', 'as', 'likely')),
#  (-0.3577701024847061, ('a', 'four-year', 'college')),
#  (-0.3577700773814857, ('past', '10', 'years')),
#  (-0.35777002792848667, ('our', 'national', 'debt')),
#  (-0.35776969151614496, ('only', 'Republican', 'candidate')),
#  (-0.357744171249628, ('gas', 'tax', 'holiday')),
#  (-0.35751318325110176, ('World', 'War', 'II')),
#  (-0.3575103790358415, ('Sen', 'Marco', 'Rubio')),
#  (-0.35608259366359774, ('500', 'billion', 'from')),
#  (-0.35572253978762397, ('the', 'Recovery', 'Act')),
#  (-0.35571826096389564, ('a', 'bad', 'idea')),
#  (0.3550666608613735, ('United', 'States', 'without')),
#  (0.35430138173433945, ('Rep', 'John', 'Barrow')),
#  (-0.3539919894751715, ('Says', 'Bill', 'Nelson')),
#  (0.35335490072491615, ('I', 'came', 'into')),
#  (-0.35293923379187386, ('Mayor', 'Tom', 'Barrett')),
#  (-0.3527918740364819, ('Nancy', 'Pelosi', 'and')),
#  (-0.3524040856679598, ('Department', 'of', 'Education')),
#  (-0.35216572591297657, ('in', 'large', 'part')),
#  (-0.3519449548608786, ('making', 'less', 'than')),
#  (-0.35170653037544686, ('on', 'college', 'campuses')),
#  (-0.35149930593645595, ('and', 'local', 'governments')),
#  (-0.3514993034743194, ('earned', 'income', 'tax')),
#  (0.35144846344392916, ('Trayvon', 'Martin')),
#  (0.35073556078209533, ('health', 'care', 'law')),
#  (0.35071341206668305, ('greenhouse', 'gases')),
#  (-0.3501525342939213, ('in', 'job', 'creation')),
#  (-0.3500712995708031, ('would', 'benefit', 'from')),
#  (0.34888656712373267, ('S', 'Rep', 'Jim')),
#  (-0.34877844778015255, ('came', 'into', 'office')),
#  (-0.34855649407545247, ('times', 'as', 'much')),
#  (0.3484520012765449, ('no', 'longer', 'have')),
#  (-0.34812687323265507, ('as', 'long', 'as')),
#  (-0.34719856581542896, ('recall', 'petitions', 'against')),
#  (-0.34719848505493706, ('Scott', 'Walker', 'eliminated')),
#  (0.3468672451970952, ('State', 'Board', 'of')),
#  (-0.3462773491371518, ('Newt', 'Gingrich')),
#  (-0.34599430513934687, ('Says', 'North', 'Carolina')),
#  (-0.34572078310061105, ('last', '15', 'years')),
#  (-0.3455645733154385, ('voted', 'against', 'funding')),
#  (-0.34499330542956275, ('Last', 'year', 'we')),
#  (-0.3449927835346782, ('losing', 'their', 'jobs')),
#  (-0.34499270436187307, ('Retirement', 'System')),
#  (-0.34499268910901126, ('Los', 'Angeles')),
#  (-0.34499266423478936, ('By', 'the', 'end')),
#  (-0.34499262582591106, ('health', 'insurance', 'exchange')),
#  (-0.3449926232889544, ('offshore', 'oil', 'drilling')),
#  (-0.3449926193888356, ('Sen', 'Harry', 'Reid')),
#  (-0.34499261458896535, ('Ferguson', 'Mo')),
#  (-0.3449926129554108, ('Right', 'now', 'we')),
#  (-0.34499259507608027, ('living', 'in', 'poverty')),
#  (-0.34499259112715525, ('off', 'the', 'hook')),
#  (-0.3449925901744565, ('Half', 'of', 'all')),
#  (-0.3449925856363183, ('less', 'than', 'men')),
#  (-0.34499258409080863, ('slash', 'funding', 'for')),
#  (-0.3449925834406538, ('Says', 'Scott', 'Walkers')),
#  (-0.3449925815689854, ('at', 'public', 'universities')),
#  (-0.34499257443567527, ('Economic', 'Development')),
#  (-0.34499257377712234, ('Braves', 'stadium')),
#  (-0.34499256277341595, ('likely', 'to', 'die')),
#  (-0.3449925623455088, ('in-person', 'voter', 'fraud')),
#  (-0.3449925523328733, ('Gulf', 'of', 'Mexico')),
#  (-0.344992545705582, ('American', 'flag', 'on')),
#  (-0.3449925380327592, ('genetically', 'modified')),
#  (-0.3449925348252977, ('the', 'death', 'penalty')),
#  (-0.3449925157643301, ('Green', 'Bay')),
#  (-0.3449925074061017, ('Associated', 'Press')),
#  (-0.3449924912764223, ('next', 'two', 'years')),
#  (-0.34499248176430397, ('than', 'anybody', 'else')),
#  (-0.34499246304460796, ('plastic', 'bags')),
#  (-0.344992413244108, ('our', 'entire', 'economy')),
#  (-0.34499227573386654, ('released', 'from', 'Guantanamo')),
#  (-0.34476930421703256, ('and', 'Saudi', 'Arabia')),
#  (-0.3446269130176186, ('Las', 'Vegas')),
#  (-0.3446192368056563, ('Wisconsin', 'is', 'dead')),
#  (0.34445146540982996, ('in', 'Saudi', 'Arabia')),
#  (-0.344372091911963, ('All', 'Aboard', 'Florida')),
#  (-0.344372091911963, ('All', 'Aboard')),
#  (0.34306679067108986, ('Supreme', 'Court', 'Justice')),
#  (-0.34291956754254466, ('Mitt', 'Romneys', 'plan')),
#  (-0.34250005120212934, ('in', 'January', '2011')),
#  (0.3417305614601769, ('health', 'care', 'option')),
#  (0.34069090758254394, ('Americans', 'will', 'lose')),
#  (-0.3406693768162822, ('Newt', 'Gingrichs')),
#  (-0.3401929201692373, ('Planned', 'Parenthood', 'and')),
#  (-0.339948883694424, ('Donald', 'Trump', 'wants')),
#  (-0.3392769756498098, ('candidate', 'Tammy', 'Baldwin')),
#  (-0.3392769756498098, ('Senate', 'candidate', 'Tammy')),
#  (-0.33925338725504117, ('he', 'was', 'sworn')),
#  (-0.33916708394361644, ('highest', 'level', 'since')),
#  (-0.3391670839436164, ('American', 'oil', 'production')),
#  (-0.33809373618242766, ('Gov', 'John', 'Kasich')),
#  (-0.33781643967709724, ('DREAM', 'Act', 'which')),
#  (0.3369440654790586, ('took', 'office', 'we')),
#  (0.3363176624336902, ('can', 'tell', 'you')),
#  (0.33622344225972167, ('Department', 'of', 'Homeland')),
#  (0.335523940095555, ('Web', 'site')),
#  (-0.33303270852557115, ('be', 'made', 'permanent')),
#  (-0.33303254142397143, ('the', 'next', 'couple')),
#  (-0.33292250225854714, ('Rick', 'Santorum', 'voted')),
#  (-0.3323691644988631, ('public', 'school', 'system')),
#  (-0.33227538737679985, ('Central', 'Falls')),
#  (-0.33215996116527907, ('Obama', 'took', 'office')),
#  (0.3317667024789883, ('Kay', 'Bailey', 'Hutchison')),
#  (0.3317667024789883, ('Bailey', 'Hutchison')),
#  (0.3317667024789882, ('Kay', 'Bailey')),
#  (-0.33146351612738334, ('Planned', 'Parenthood', 'is')),
#  (-0.3314634767698843, ('infant', 'mortality')),
#  (-0.3314634738696467, ('would', 'take', 'away')),
#  (-0.3314634698227584, ('womens', 'health', 'care')),
#  (-0.3314634260504181, ('crossed', 'the', 'border')),
#  (-0.33146342329887934, ('high', 'school', 'graduates')),
#  (-0.3313926735126602, ('near', 'the', 'bottom')),
#  (-0.33126695771581616, ('Barack', "Obama's", 'plan')),
#  (-0.33079379249427615, ('on', 'Fox', 'News')),
#  (-0.3302277929314106, ('nearly', '90', 'percent')),
#  (-0.32963028696993424, ('Last', 'week', 'the')),
#  (-0.32938556149857784, ('Wendy', 'Davis')),
#  (-0.3281530742455718, ('Thom', 'Tillis')),
#  (0.3277959906299308, ('give', 'Social', 'Security')),
#  (-0.3273482850353124, ('deciding', 'vote', 'for')),
#  (-0.32673395074849215, ('25', 'million', 'Americans')),
#  (-0.3265061339229586, ('Polls', 'show', 'that')),
#  (0.32634293788706104, ('Irans', 'nuclear', 'program')),
#  (0.325047363695819, ('Kendrick', 'Meek')),
#  (-0.3247334917650059, ('net', 'new', 'jobs')),
#  (-0.3245430702720701, ('far', 'greater', 'than')),
#  (0.3241672239829765, ('nearly', '4', 'billion')),
#  (-0.32349982507560016, ('Paul', 'Ryans', 'Medicare')),
#  (-0.3232608776585473, ('many', 'of', 'whom')),
#  (-0.321993562055756, ('America', 'right', 'now')),
#  (-0.32199336913308474, ('violent', 'crime', 'was')),
#  (-0.3219933281940405, ('Michael', 'Bennet')),
#  (-0.32199326376979387, ('has', 'never', 'once')),
#  (-0.3219932231017463, ('Fort', 'Worth')),
#  (-0.3219932221862488, ('Blue', 'Cross')),
#  (-0.32199319904744095, ('tens', 'of', 'millions')),
#  (-0.3219931967880273, ('2.5', 'million', 'jobs')),
#  (-0.3219931835165422, ('war', 'in', 'Afghanistan')),
#  (-0.3219931755327763, ('our', 'nations', 'history')),
#  (-0.32199317073386874, ('has', 'nearly', 'doubled')),
#  (-0.32199316935762373, ('per-pupil', 'cost', 'in')),
#  (-0.3219931686071237, ('their', 'tax', 'returns')),
#  (-0.32199316852527726, ('Sharron', 'Angle')),
#  (-0.3219931644162256, ('do', 'not', 'want')),
#  (-0.3219931587873773, ('economic', 'stimulus', 'bill')),
#  (-0.32199314034141935, ('on', 'death', 'row')),
#  (-0.3219931389541726, ('New', 'York', 'Mayor')),
#  (-0.32199313472744473, ('the', 'Ohio', 'Turnpike')),
#  (-0.32199313429894105, ('gallon', 'of', 'gasoline')),
#  (-0.3219931327354689, ('times', 'as', 'many')),
#  (-0.3219931327256933, ('overwhelming', 'majority', 'of')),
#  (-0.3219931305842224, ('corporate', 'tax', 'loopholes')),
#  (-0.32199312850117684, ('in', 'Broward', 'County')),
#  (-0.3219931283540245, ('Chuck', 'Hagel')),
#  (-0.3219931272344181, ('Goldman', 'Sachs')),
#  (-0.3219931270732399, ('than', 'any', 'previous')),
#  (-0.32199312351416426, ('as', 'simple', 'as')),
#  (-0.3219931230027462, ('wants', 'to', 'add')),
#  (-0.32199312153968834, ('Milwaukee', 'County', 'Board')),
#  (-0.3219931188208522, ('of', 'human', 'trafficking')),
#  (-0.32199311608804554, ('Carly', 'Fiorina')),
#  (-0.3219931160315249, ('high', 'school', 'dropout')),
#  (-0.32199311145504855, ('Marco', 'Rubio', 'was')),
#  (-0.32199310814274307, ('a', 'D', 'C')),
#  (-0.32199310647781604, ('every', 'day', 'because')),
#  (-0.32199310461326835, ('my', 'eight', 'years')),
#  (-0.3219931042953331, ('If', 'Rhode', 'Island')),
#  (-0.32199310398658854, ('this', 'fiscal', 'year')),
#  (-0.32199309848702734, ('dont', 'have', 'access')),
#  (-0.3219930976477515, ('The', 'White', 'House')),
#  (-0.3219930952375586, ('Federal', 'Reserve', 'Chairman')),
#  (-0.3219930938029316, ('texting', 'while', 'driving')),
#  (-0.3219930900138992, ('to', 'climate', 'change')),
#  (-0.32199308795741766, ('legislation', 'supported', 'by')),
#  (-0.32199308651372205, ('baby', 'boomers')),
#  (-0.3219930857821035, ('JoAnne', 'Kloppenburg')),
#  (-0.3219930846228686, ('the', 'highest', 'bidder')),
#  (-0.32199308331131404, ('richest', '1', 'percent')),
#  (-0.32199308066931565, ('Texas', 'school', 'districts')),
#  (-0.3219930806096131, ('Says', 'George', 'LeMieux')),
#  (-0.32199307976148744, ('had', 'the', 'courage')),
#  (-0.32199307904907915, ('Less', 'than', 'half')),
#  (-0.3219930766808742, ('1', 'million', 'Texans')),
#  (-0.32199307478206524, ('even', 'though', 'it')),
#  (-0.32199307388641235, ('high', 'school', 'diploma')),
#  (-0.32199307315044434, ('Bain', 'Capital')),
#  (-0.3219930726390505, ('it', 'more', 'difficult')),
#  (-0.32199307212532857, ('in', 'New', 'England')),
#  (-0.3219930719737703, ('collective', 'bargaining', 'changes')),
#  (-0.3219930704306877, ('the', 'Veterans', 'Administration')),
#  (-0.321993070211035, ('will', 'be', 'required')),
#  (-0.3219930696368649, ('the', 'Vietnam', 'War')),
#  (-0.3219930679611327, ('led', 'the', 'effort')),
#  (-0.32199306787633303, ('what', 'Donald', 'Trump')),
#  (-0.32199306405607186, ('population', 'has', 'grown')),
#  (-0.3219930619647716, ('Suzanne', 'Bonamici')),
#  (-0.32199306169529784, ('last', 'few', 'years')),
#  (-0.3219930608714132, ('funding', 'per', 'pupil')),
#  (-0.32199306015026247, ('making', 'sure', 'that')),
#  (-0.3219930579224034, ('Californias', 'Prop')),
#  (-0.3219930565172566, ('private', 'sector', 'job')),
#  (-0.32199305623525243, ('likely', 'to', 'stay')),
#  (-0.321993056172749, ('Members', 'of', 'Congress')),
#  (-0.32199305516073723, ('her', 'property', 'taxes')),
#  (-0.3219930507689015, ('real', 'unemployment', 'rate')),
#  (-0.3219930504956686, ('Roy', 'Barnes')),
#  (-0.3219930497893423, ('the', 'oil', 'spill')),
#  (-0.3219930472654806, ('track', 'record', 'of')),
#  (-0.32199304722605865, ('The', 'Obama', 'administrations')),
#  (-0.3219930437205758, ('about', '75', 'percent')),
#  (-0.32199304217523705, ('other', '49', 'states')),
#  (-0.32199303756075787, ('at', 'least', '80')),
#  (-0.32199303383562894, ('cents', 'a', 'gallon')),
#  (-0.32199303280927605, ('Austin', 'school', 'district')),
#  (-0.3219930323581847, ('above', '8', 'percent')),
#  (-0.3219930258755352, ('three', 'years', 'ago')),
#  (-0.3219930221788645, ('Ronald', 'Reagan', 'raised')),
#  (-0.3219930153347763, ('Planned', 'Parenthood', 'does')),
#  (-0.32199301498032984, ('10', 'years', 'ago')),
#  (-0.32199301393471536, ('stopped', 'looking', 'for')),
#  (-0.3219930069527247, ('of', 'Wisconsin', 'System')),
#  (-0.32199300306799156, ('median', 'household', 'income')),
#  (-0.32199299675191184, ('less', 'per', 'student')),
#  (-0.3219929905727846, ('economic', 'stimulus', 'package')),
#  (-0.3219929810704174, ('pension', 'system', 'is')),
#  (-0.3219929633364449, ('The', 'Clinton', 'Foundation')),
#  (-0.32199295610127265, ('Falcons', 'stadium')),
#  (-0.3219929454183245, ('U', 'S', 'Reps')),
#  (-0.32199291195963775, ('Twitter', 'account', 'has')),
#  (-0.32199290876406705, ('16', 'million', 'people')),
#  (-0.3219928998132734, ('Department', 'of', 'Justice')),
#  (-0.3219928945296965, ('prime', 'minister')),
#  (-0.32199288055455105, ('About', '40', 'percent')),
#  (-0.32199276003452015, ('Reid', 'Ribble')),
#  (-0.3209368286946453, ('you', 'can', 'keep')),
#  (-0.3205423339008081, ('created', 'zero', 'jobs')),
#  (-0.3200066434409109, ('our', 'dependence', 'on')),
#  (-0.3181507378338573, ('lose', 'their', 'jobs')),
#  (-0.318063567048598, ('Postal', 'Service')),
#  (-0.3180630594875234, ('Sandy', 'Hook')),
#  (-0.3177956560923167, ('of', 'Rhode', 'Island')),
#  (-0.3177854825386053, ('payroll', 'tax', 'cut')),
#  (-0.31750466127012095, ('look', 'at', 'what')),
#  (-0.31673884076174874, ('Mitt', 'Romney', 'has')),
#  (-0.31628621008807556, ('Today', 'there', 'are')),
#  (-0.31589770387849747, ('Jeb', 'Bush', 'not')),
#  (0.31519525350846683, ('cast', 'the', 'deciding')),
#  (-0.3151242238305393, ('past', 'four', 'years')),
#  (-0.3143894002569875, ('787', 'billion', 'stimulus')),
#  (-0.314330739776391, ('Says', 'Marco', 'Rubio')),
#  (0.31431167054253195, ('Marcy', 'Kaptur')),
#  (-0.31366425411528503, ('Charlie', 'Crist', 'was')),
#  (-0.3103950586012818, ('Nancy', 'Pelosi', 'said')),
#  (0.31032415531766894, ('raise', 'taxes', 'on')),
#  (-0.3096084921102374, ('cant', 'find', 'a')),
#  (0.3091951563174296, ('filibusters', 'on', 'presidential')),
#  (0.3091951563174296, ('rules', 'for', 'filibusters')),
#  (0.3091951563174296, ('on', 'presidential', 'nominees')),
#  (0.3091951563174296, ('changing', 'the', 'rules')),
#  (0.3091951563174296, ('for', 'filibusters', 'on')),
#  (-0.30888435021844424, ('for', 'Clunkers', 'program')),
#  (-0.30826079971972753, ('no', 'matter', 'where')),
#  (-0.3081734329083636, ('on', 'food', 'stamps')),
#  (-0.3071713941875178, ('Fannie', 'and', 'Freddie')),
#  (-0.3070220286077988, ('Dwight', 'Eisenhower')),
#  (0.30657331760273204, ('common', 'forms', 'of')),
#  (0.30657331760273204, ('forms', 'of', 'birth')),
#  (0.30657331760273204, ('of', 'birth', 'control')),
#  (-0.3064114464244754, ('Fox', 'News', 'is')),
#  (-0.3063346941454798, ('new', 'private-sector', 'jobs')),
#  (-0.30633465026223833, ('highest', 'property', 'taxes')),
#  (0.30515546479442085, ('replacing', 'them', 'with')),
#  (0.3051083124338928, ('less', 'than', '1')),
#  (-0.30505893944042617, ('Head', 'Start')),
#  (0.30492344668010385, ('two', 'weeks', 'ago')),
#  (-0.30439159695653406, ('who', 'were', 'killed')),
#  (-0.3043177185725528, ('he', 'never', 'supported')),
#  (-0.3042032239043111, ('at', 'an', 'all-time')),
#  (0.3035835061884527, ('Thomas', 'Jefferson', 'said')),
#  (0.30358350618845265, ('Says', 'Thomas', 'Jefferson')),
#  (0.3034423478295733, ('give', 'amnesty', 'to')),
#  (-0.30344024995998453, ('Sean', 'Duffy')),
#  (-0.3005386613630176, ('dead', 'last', 'in')),
#  (-0.30002301101285067, ('Sen', 'Mark', 'Begich')),
#  (-0.29892881144610756, ('pork', 'barrel')),
#  (-0.29850429093255226, ('Phil', 'Gingrey')),
#  (0.29839950439355734, ('President', 'Ronald', 'Reagan')),
#  (-0.29835763769342716, ('for', 'Planned', 'Parenthood')),
#  (-0.29815198111383723, ('Confederate', 'battle', 'flag')),
#  (-0.29815198111383723, ('The', 'Confederate', 'battle')),
#  (-0.29815198111383723, ('Confederate', 'battle')),
#  (0.2976804439947155, ('public', 'school', 'funding')),
#  (-0.29657258308264095, ('adjusted', 'for', 'inflation')),
#  (-0.2962037434966218, ('than', 'any', 'other')),
#  (-0.2948814551172921, ('access', 'to', 'reproductive')),
#  (-0.2948813366229851, ('reproductive', 'health', 'care')),
#  (-0.29443170949989056, ('was', 'governor', 'Massachusetts')),
#  (-0.29324366906400223, ('lost', '400,000', 'jobs')),
#  (0.29300478922543444, ('S', 'Rep', 'Paul')),
#  (-0.29272102689302343, ('Rick', 'Perry', 'was')),
#  (-0.2927210070403445, ('no', 'tax', 'increases')),
#  (-0.2927209944193223, ('for', 'illegal', 'aliens')),
#  (-0.2927209933910863, ('gone', 'too', 'far')),
#  (-0.2927209724293213, ('unemployment', 'under', '8')),
#  (-0.29272097230275224, ('As', 'a', 'senator')),
#  (-0.2927208469533703, ('Pell', 'Grants')),
#  (-0.29272054329457375, ('Lee', 'Leffingwell')),
#  (-0.29271035256746814, ('the', 'most', 'restrictive')),
#  (-0.2927103360643139, ('Franklin', 'Roosevelt')),
#  (-0.29221115976152373, ('I', 'was', 'mayor')),
#  (-0.2917089056017004, ('depend', 'on', 'Social')),
#  (-0.2915684971907614, ("it's", 'okay')),
#  (0.29113674906760845, ('Social', 'Security', 'was')),
#  (0.2909506967271295, ('the', 'Supreme', 'Court')),
#  (-0.28963588784375593, ('Lincoln', 'Chafee')),
#  (0.28916613297793026, ('been', 'laid', 'off')),
#  (0.28916613297793026, ('have', 'been', 'laid')),
#  (-0.28888845245919414, ('Donald', 'Trump', 'thinks')),
#  (0.28859187454694946, ('your', 'tax', 'dollars')),
#  (-0.2883835464880622, ('light', 'bulbs')),
#  (-0.28797436127293874, ('killed', 'by', 'gunfire')),
#  (-0.28749595304389114, ('Republican', 'Party', 'platform')),
#  (0.28714768390593026, ('the', 'Islamic', 'State')),
#  (-0.2868530476951775, ('a', 'pre-existing', 'condition')),
#  (-0.2868530476951775, ('pre-existing', 'condition')),
#  (0.2866520317974781, ('When', 'you', 'look')),
#  (-0.28598384757411455, ('forced', 'to', 'resign')),
#  (-0.2856213684091131, ('Donald', 'Trump', 'says')),
#  (-0.2850094203677219, ('Barack', 'Obamas', 'policies')),
#  (-0.28399361857761335, ('Says', 'Travis', 'County')),
#  (-0.2839933772381665, ('any', 'major', 'country')),
#  (0.28202046209755227, ('Cash', 'for', 'Clunkers')),
#  (0.28118048228874604, ('stem', 'cell', 'research')),
#  (0.28118048228874604, ('stem', 'cell')),
#  (0.2809042141175602, ('in', 'New', 'Hampshire')),
#  (-0.28080792114030595, ('Austin', 'mayoral', 'candidate')),
#  (-0.2796328084162442, ('overturning', 'Roe')),
#  (-0.2790392170942148, ('Social', 'Security', 'and')),
#  (0.2767326882155402, ('Todd', 'Akin')),
#  (-0.2763949602614703, ('could', 'lose', 'their')),
#  (-0.27615812629939235, ('our', 'gross', 'domestic')),
#  (-0.2758493324422341, ('Care', 'Act', 'was')),
#  (0.2752484127801354, ('leads', 'the', 'nation')),
#  (-0.2749852243045966, ('U', 'S', 'born')),
#  (-0.2749505872540843, ('cell', 'phones')),
#  (-0.2749505395440453, ('a', 'blank', 'check')),
#  (-0.2738987915219176, ('When', 'it', 'comes')),
#  (0.27243105445770166, ('Judge', 'Sotomayor')),
#  (-0.2717339305026035, ('35', 'years', 'old')),
#  (-0.27137861197910346, ('when', 'I', 'came')),
#  (-0.26953149488079386, ('are', 'openly', 'serving')),
#  (-0.26953149488079386, ('openly', 'serving', 'in')),
#  (-0.26953149488079386, ('are', 'socialists', 'who')),
#  (-0.26953149488079386, ('socialists', 'who', 'are')),
#  (-0.26953149488079386, ('who', 'are', 'openly')),
#  (-0.26952275474774273, ('Says', 'Ted', 'Cruz')),
#  (-0.2692690826493886, ('S', 'Sen', 'Bill')),
#  (-0.26832983834322355, ('the', 'Great', 'Lakes')),
#  (-0.2683281047453475, ('Supreme', 'Court', 'candidate')),
#  (-0.2683277596113674, ('On', 'whether', 'he')),
#  (-0.26832773886493216, ('if', 'you', 'want')),
#  (-0.2683277273965807, ('As', 'many', 'as')),
#  (-0.2683276961180032, ('led', 'the', 'fight')),
#  (-0.2683276821475209, ('nearly', '1', 'trillion')),
#  (-0.2683276689358204, ('Americans', 'will', 'spend')),
#  (-0.26832764961481653, ('Dave', 'Brat')),
#  ...]

# %%
coefs_and_features[:10]
# Out:
# [(1.486268592731033, ('Attorney', 'General', 'Eric')),
#  (1.414297692532734, ('Supreme', 'Court', 'nominee')),
#  (1.4103088208769277, ('wildly', 'unpopular')),
#  (1.4089777018878118, ('Terry', 'McAuliffe')),
#  (1.4012763618629411, ('For', 'every', 'one')),
#  (1.3928195472247873, ('takeover', 'of', 'healthcare')),
#  (1.3721011660292852, ('babies', 'born', 'in')),
#  (1.3692931475036962, ('and', 'your', 'doctor')),
#  (1.3563602197005926, ('278,000', 'per', 'job')),
#  (1.3499320430781183, ('voted', 'six', 'times'))]

# %%
coefs_and_features[-10:]
# Out:
# [(0.0, ('citizenship', 'for', 'illegal')),
#  (0.0, ('are', 'unemployed', 'or')),
#  (0.0, ('total', 'amount', 'of')),
#  (0.0, ('Bank', 'of', 'America')),
#  (0.0, ('where', 'you', 'can')),
#  (0.0, ('childhood', 'obesity')),
#  (0.0, ('standing', 'committees')),
#  (0.0, ('when', 'I', 'took')),
#  (0.0, ('pot', 'shops')),
#  (0.0, ('current', 'health', 'care'))]

# %%
coefs_and_features[-10:]
# Out:
# [(0.0, ('citizenship', 'for', 'illegal')),
#  (0.0, ('are', 'unemployed', 'or')),
#  (0.0, ('total', 'amount', 'of')),
#  (0.0, ('Bank', 'of', 'America')),
#  (0.0, ('where', 'you', 'can')),
#  (0.0, ('childhood', 'obesity')),
#  (0.0, ('standing', 'committees')),
#  (0.0, ('when', 'I', 'took')),
#  (0.0, ('pot', 'shops')),
#  (0.0, ('current', 'health', 'care'))]

# %%
n_best = 750
best_tokens = []

# for cf in coefs_and_features[-n_best:]:
#     best_tokens.append(cf[1])

for cf in coefs_and_features[:n_best]:
    best_tokens.append(cf[1])
    
print(best_tokens[:10])
    
with open("../../data/processed/liarpantsfire_best_terms.txt", "w") as f:
    for token in best_tokens:
        f.write(" ".join(token) + "\n")
# Out:
# [('Attorney', 'General', 'Eric'), ('Supreme', 'Court', 'nominee'), ('wildly', 'unpopular'), ('Terry', 'McAuliffe'), ('For', 'every', 'one'), ('takeover', 'of', 'healthcare'), ('babies', 'born', 'in'), ('and', 'your', 'doctor'), ('278,000', 'per', 'job'), ('voted', 'six', 'times')]
